# %%
import selenium
# import pyttsx3
from selenium import webdriver
import time
import os
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.action_chains import ActionChains
# import speech_recognition as sr
import pyautogui
from selenium.webdriver.common.by import By
from selenium.common.exceptions import NoSuchElementException
from bs4 import BeautifulSoup
from collections import defaultdict
import pandas as pd
import numpy as np

# %%
options = Options()
options.add_argument("start-maximized")
options.add_argument("--disable-extensions")

options.add_experimental_option("prefs", { \
"profile.default_content_setting_values.media_stream_mic": 1,
"profile.default_content_setting_values.media_stream_camera": 1,
"profile.default_content_setting_values.geolocation": 1,
"profile.default_content_setting_values.notifications": 1
})

# %% [markdown]
# ### Image Segregation

# %%
def getprojectinfo(reflist):   
    
    
    driver = webdriver.Chrome(options=options,
                                  executable_path=ChromeDriverManager().install())

    information = defaultdict(list)

        # opening mahaonline webiee!

    driver.get("https://maharerait.mahaonline.gov.in/SearchList/Search")
    time.sleep(2)

        # clicking on the projectdetails

    driver.find_element_by_xpath('//*[@id="TheForm"]/div[1]/div[3]/div/div/div[2]/div[2]/a').click()
    time.sleep(2)

        ## click on registered projects

    driver.find_element_by_xpath('//*[@id="Agent"]').click()
    time.sleep(2)


        ## clicking on Advance button

    driver.find_element_by_xpath('//*[@id="btnAdvance"]').click()
    time.sleep(2)


        ## selecting element as Maharastra

    driver.find_element_by_xpath('//*[@id="State"]').send_keys('MAHARASTRA')
    time.sleep(2)


        ## Selecting the city as Mumbai 

    driver.find_element_by_xpath('//*[@id="District"]').send_keys('Mumbai City')
    time.sleep(2)


        # Click on the search

    driver.find_element_by_xpath('//*[@id="btnSearch"]').click()

    time.sleep(2)

    details = []
    
    window_before = driver.window_handles[0]

    for col in range(4):

            for i in range(0,len(reflist)):

                widow_before = driver.window_handles[0]

                driver.find_element_by_xpath(reflist[i]).click()

                time.sleep(1)


                current_tab=driver.window_handles[1]

                driver.switch_to.window(current_tab)


                try:

                    src = driver.find_element_by_xpath('//*[@id="DivPInfo"]/div[1]/div[2]/div[2]/img').get_attribute("src")
                    details.append(src)



                except:

                     details.append(' ')


                driver.close()
                driver.switch_to_window(window_before)
                
                
    return details
  

# driver.switch_to_window(window_before)

# driver.switch_to_window(window_before)
# driver.find_element_by_xpath('//*[@id="btnNext"]').click()
# time.sleep(1)

# %%
reflisttcreate = ['//*[@id="gridview"]/div[1]/div/table/tbody/tr['+str(int(i))+']'+'/td[4]/b/a' for i in range(1,51)]

# %%
details = getprojectinfo(reflisttcreate)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 91.0.4472
# [WDM] - Get LATEST driver version for 91.0.4472
# [WDM] - Driver [C:\Users\meet\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache
# <ipython-input-4-17c1966d4092>:82: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(window_before)

# %%
details
# Out:
# ['https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  ' ',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  ' ',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  ' ',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  ' ',
#  ' ',
#  ' ',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture',
#  'https://maharerait.mahaonline.gov.in/Preview/GetPicture']

# %%
detailsdf = pd.DataFrame(details,columns=['Image Src'])
detailsdf.head(2)
# Out:
#                                            Image Src
# 0  https://maharerait.mahaonline.gov.in/Preview/G...
# 1  https://maharerait.mahaonline.gov.in/Preview/G...

# %% [markdown]
# ## Individual Type

# %%
def getprojectinfo(reflist):   
    
    
    driver = webdriver.Chrome(options=options,
                                  executable_path=ChromeDriverManager().install())

    information = defaultdict(list)

        # opening mahaonline webiee!

    driver.get("https://maharerait.mahaonline.gov.in/SearchList/Search")
    time.sleep(2)

        # clicking on the projectdetails

    driver.find_element_by_xpath('//*[@id="TheForm"]/div[1]/div[3]/div/div/div[2]/div[2]/a').click()
    time.sleep(2)

        ## click on registered projects

    driver.find_element_by_xpath('//*[@id="Agent"]').click()
    time.sleep(2)


        ## clicking on Advance button

    driver.find_element_by_xpath('//*[@id="btnAdvance"]').click()
    time.sleep(2)


        ## selecting element as Maharastra

    driver.find_element_by_xpath('//*[@id="State"]').send_keys('MAHARASTRA')
    time.sleep(2)


        ## Selecting the city as Mumbai 

    driver.find_element_by_xpath('//*[@id="District"]').send_keys('Mumbai City')
    time.sleep(2)


        # Click on the search

    driver.find_element_by_xpath('//*[@id="btnSearch"]').click()

    time.sleep(2)

    details = []
    
    window_before = driver.window_handles[0]

    for col in range(4):

            for i in range(0,len(reflist)):

                widow_before = driver.window_handles[0]

                driver.find_element_by_xpath(reflist[i]).click()

                time.sleep(1)


                current_tab=driver.window_handles[1]

                driver.switch_to.window(current_tab)


                try:

                    src = driver.find_element_by_xpath('//*[@id="divInfoType"]/div/div[2]').text
                    details.append(src)



                except:

                     details.append(' ')


                driver.close()
                driver.switch_to_window(window_before)
                
                
    return details
  

# driver.switch_to_window(window_before)

# driver.switch_to_window(window_before)
# driver.find_element_by_xpath('//*[@id="btnNext"]').click()
# time.sleep(1)

# %%
detailsnew = getprojectinfo(reflisttcreate)
# Out:
# [WDM] - ====== WebDriver manager ======
# [WDM] - Current google-chrome version is 91.0.4472
# [WDM] - Get LATEST driver version for 91.0.4472
# [WDM] - Driver [C:\Users\meet\.wdm\drivers\chromedriver\win32\91.0.4472.19\chromedriver.exe] found in cache
# <ipython-input-11-88b43d2ef890>:82: DeprecationWarning: use driver.switch_to.window instead
#   driver.switch_to_window(window_before)

# %%
detailsnew
# Out:
# ['Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Other Than Individual',
#  'Individual',
#  'Individual']

# %%
detailsdf['Information Type'] = detailsnew
detailsdf
# Out:
#                                              Image Src       Information Type
# 0    https://maharerait.mahaonline.gov.in/Preview/G...             Individual
# 1    https://maharerait.mahaonline.gov.in/Preview/G...             Individual
# 2    https://maharerait.mahaonline.gov.in/Preview/G...             Individual
# 3    https://maharerait.mahaonline.gov.in/Preview/G...             Individual
# 4    https://maharerait.mahaonline.gov.in/Preview/G...             Individual
# ..                                                 ...                    ...
# 195                                                     Other Than Individual
# 196                                                     Other Than Individual
# 197                                                     Other Than Individual
# 198  https://maharerait.mahaonline.gov.in/Preview/G...             Individual
# 199  https://maharerait.mahaonline.gov.in/Preview/G...             Individual
#
# [200 rows x 2 columns]

# %%
detailsdf = detailsdf[['Information Type','Image Src']]
detailsdf.head(2)
# Out:
#   Information Type                                          Image Src
# 0       Individual  https://maharerait.mahaonline.gov.in/Preview/G...
# 1       Individual  https://maharerait.mahaonline.gov.in/Preview/G...

# %%
detailsdf.to_csv('Individual info.csv',index = False)
